# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('./data.csv')

# %%
sns.histplot(x='price', data=df)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.countplot(x='brand', data=df, order=df.brand.value_counts().iloc[:10].index).tick_params(axis='x', rotation=45)

# %%
sns.countplot(x='model', data=df, order=df.model.value_counts().iloc[:10].index).tick_params(axis='x', rotation=45)

# %%
sns.countplot(x='type', data=df, order=df.type.value_counts().iloc[:10].index).tick_params(axis='x', rotation=45)

# %%
sns.countplot(x='transmission', data=df)
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
sns.countplot(x='wheel_drive', data=df)
# Out:
# <Axes: xlabel='wheel_drive', ylabel='count'>

# %%
sns.countplot(x='external_color', data=df).tick_params(axis='x', rotation=45)

# %%
sns.countplot(x='internal_color', data=df).tick_params(axis='x', rotation=45)

# %%
sns.countplot(x='year', data=df).tick_params(axis='x', rotation=90)

# %%
sns.scatterplot(x='year', y='price', data=df)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
sns.countplot(x='type', data=df).tick_params(axis='x', rotation=45)

# %%
sns.countplot(x='fuels', data=df)
# Out:
# <Axes: xlabel='fuels', ylabel='count'>

# %%
sns.scatterplot(x='fuels', y='price', data=df)
# Out:
# <Axes: xlabel='fuels', ylabel='price'>
